# %% [markdown]
# <a href="https://colab.research.google.com/github/isg-data/insurance_eda/blob/main/Dashboard_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
system("git clone https://github.com/isg-data/insurance_eda.git")
setwd("insurance_eda")
install.packages(c("flexdashboard", "rmarkdown"))
rmarkdown::render("dashboard.Rmd")
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
#
# processing file: dashboard.Rmd
# 1/28
# 2/28 [setup]
# 3/28
# 4/28 [unnamed-chunk-1]
# 5/28
# 6/28 [unnamed-chunk-2]
# 7/28
# 8/28 [unnamed-chunk-3]
# 9/28
# 10/28 [unnamed-chunk-4]
# 11/28
# 12/28 [unnamed-chunk-5]
# 13/28
# 14/28 [unnamed-chunk-6]
# 15/28
# 16/28 [unnamed-chunk-7]
# 17/28
# 18/28 [unnamed-chunk-8]
# 19/28
# 20/28 [unnamed-chunk-9]
# 21/28
# 22/28 [unnamed-chunk-10]
# 23/28
# 24/28 [unnamed-chunk-11]
# 25/28
# 26/28 [unnamed-chunk-12]
# 27/28
# 28/28 [unnamed-chunk-13]
# output file: dashboard.knit.md
# ...

# %%
# Prüfen, ob die Datei existiert
file.exists("dashboard.html")
# Out:
# [1] TRUE
